# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression as LR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
x = np.array([1400, 1600, 1700, 1875, 1100, 1550, 2350, 2450, 1425, 1700]) # square
y = np.array([245, 312, 279, 308, 199, 219, 405, 324, 319, 255])
x = x/np.max(x)
y = x/np.max(y)

print('x_normalize = ',x, '\n y_normalize = %f',y)
# Out:
# x_normalize =  [0.57142857 0.65306122 0.69387755 0.76530612 0.44897959 0.63265306
#  0.95918367 1.         0.58163265 0.69387755]
#  y_normalize = %f [0.00141093 0.0016125  0.00171328 0.00188964 0.00110859 0.00156211
#  0.00236835 0.00246914 0.00143613 0.00171328]

# %%
alpha = 10**(-3)
#theta = np.zeros((2,1))
theta00 = 0
theta01 = 0
epochs = 100000
m = 10 # len(X)

# %%
for i in range (epochs):
    temp00 = np.sum(theta00 + theta01 * x.T - y)/m #theta0 - Alpha * (np.sum(error)) / m
    temp01 = np.sum((theta01 + theta01 * x.T - y)*x) / m
    theta00 = theta00 - alpha * temp00
    theta01 = theta01 - alpha * temp01
    J = np.sum((theta00+theta01*x.T-y) ** 2) / (2 * m)

### nhiem vu:  dua cac pt trong for thanh dang matrix va chi 1 dong theta = ... (matran 2 bien)
### dung x_bar, them hang 1, scaling truoc khi them hang 1

print('D0=',theta00)
print('D1=',theta01)
print('J=',J)

plt.scatter(x, y, color='orange', marker='*', label='Scatter')
plt.xlabel('square (feet)')
plt.ylabel('House price ($1000s)')
plt.plot(x, theta00 + theta01 * x, color='blue', label='Linear Regression')
plt.legend()  # Hiển thị chú thích##
plt.show()
# Out:
# D0= 0.0010110249550024084
# D1= [0.00078894 0.00090495 0.00096296 0.00106447 0.00061492 0.00087595
#  0.00134    0.00139801 0.00080344 0.00096296]
# J= 2.5787808478149817e-09

# %%
########################### KẾT QUẢ THỰC HIỆN DÙNG HÀM THƯ VIỆN LR().FIT() ####################################################
########### --> kết quả dùng để so sánh với giải thuật thực thi

x = np.array([1400, 1600, 1700, 1875, 1100, 1550, 2350, 2450, 1425, 1700]) # square
y = np.array([245, 312, 279, 308, 199, 219, 405, 324, 319, 255])

# Chia dữ liệu thành tập huấn luyện và tập kiểm thử
X_train, X_test, y_train, y_test = train_test_split(x.reshape(-1, 1), y, test_size=0.2, random_state=42)


# Huấn luyện mô hình
GD = LR().fit(X_train, y_train)

# Dự đoán trên tập kiểm thử
y_pred = GD.predict(X_test)

# Hiển thị hệ số và sai số trung bình bình phương trên tập kiểm thử
print("Hệ số theta0 (intercept):", GD.intercept_)
print("Hệ số theta1 (slope):", GD.coef_[0])
print("Sai số trung bình bình phương trên tập kiểm thử:", mean_squared_error(y_test, y_pred))

# Vẽ đồ thị
plt.scatter(x, y, color='orange', marker='*', label='Scatter')
plt.plot(x, GD.predict(x.reshape(-1, 1)), color='blue', label='Linear Regression')
plt.xlabel('Square (feet)')
plt.ylabel('House Price ($1000s)')
plt.legend()
plt.show()
# Out:
# Hệ số theta0 (intercept): 51.15633901219968
# Hệ số theta1 (slope): 0.1291857902939754
# Sai số trung bình bình phương trên tập kiểm thử: 4973.274832886896

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 6
#       1 from IPython.display import HTML
#       2 HTML('''
#       3     <script type="text/javascript>
#       4         IPython.notebook.kernel.execute("URL = '" + window.location + "'")
#       5     </script>''')
# ----> 6 print(URL)
#
# NameError: name 'URL' is not defined
